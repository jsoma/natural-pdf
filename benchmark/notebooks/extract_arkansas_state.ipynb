# %%
from natural_pdf import PDF

pdf = PDF("../pdfs/30.pdf")
page = pdf.pages[0]

# %%
# Explore the page
page.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1275x1651>

# %%
(
    page
    .find(text="Am. Ind")
    .below(until='text:contains(Total)', width='element', include_source=True)
    .find_all('text')
    .show()
)
# Out:
# <PIL.Image.Image image mode=RGBA size=1275x1651>
