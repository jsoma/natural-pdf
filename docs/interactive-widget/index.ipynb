# %% [markdown]
# # Interactive widget
#
# This is the best possible way, in all of history, to explore a PDF.

# %%
from natural_pdf import PDF

pdf = PDF("https://github.com/jsoma/natural-pdf/raw/refs/heads/main/pdfs/01-practice.pdf")
page = pdf.pages[0]

page.viewer()
# Out:
#             <div id="pdf-viewer-aa018e04" class="pdf-viewer" style="position: relative; font-family: Arial, sans-serif;">
#                 <div class="toolbar" style="margin-bottom: 10px; padding: 5px; background-color: #f0f0f0; border-radius: 4px;">
#                     <button id="pdf-viewer-aa018e04-zoom-in" style="margin-right: 5px;">Zoom In (+)</button>
#                     <button id="pdf-viewer-aa018e04-zoom-out" style="margin-right: 5px;">Zoom Out (-)</button>
#                     <button id="pdf-viewer-aa018e04-reset-zoom" style="margin-right: 5px;">Reset</button>
#                 </div>
#                 <div style="display: flex; flex-direction: row;">
#                     <div class="pdf-outer-container" style="position: relative; overflow: hidden; border: 1px solid #ccc; flex-grow: 1;">
#                         <div id="pdf-viewer-aa018e04-zoom-pan-container" class="zoom-pan-container" style="position: relative; width: fit-content; height: fit-content; transform-origin: top left; cursor: grab;">
#                         <!-- The image is rendered at scale, so its dimensions match scaled coordinates -->
#                             <img src="data:image/png;base64,..." style="display: block; max-width: none; height: auto;" />
#                         <div id="pdf-viewer-aa018e04-elements-layer" class="elements-layer" style="position: absolute; top: 0; left: 0; width: 100%; height: 100%; pointer-events: none;">
#
#                         </div>
#                         <div id="pdf-viewer-aa018e04-svg-layer" class="svg-layer" style="position: absolute; top: 0; left: 0; width: 100%; height: 100%; pointer-events: none;">
#                             <!-- SVG viewport should match the scaled image size -->
#                             <svg width="100%" height="100%">
#
#                             <div class="pdf-element" data-element-id="0" style="position: absolute; pointer-events: auto; cursor: pointer; left: 375.0px; top: 27.0px; width: 180.0px; height: 35.0px; background-color: rgba(200, 200, 200, 0.3); border: 1px dashed transparent; "></div>
#
#                             <rect data-element-id="0" x="375.0" y="27.0" width="180.0" height="35.0"
#                                   fill="none" stroke="rgba(255, 165, 0, 0.85)" stroke-width="1.5" />
#
#                             <div class="pdf-element" data-element-id="1" style="position: absolute; pointer-events: auto; cursor: pointer; left: 385.0px; top: 35.66px; width: 156.97000000000003px; height: 8.0px; background-color: rgba(200, 200, 200, 0.3); border: 1px dashed transparent; "></div>
#
#                             <rect data-element-id="1" x="385.0" y="35.66" width="156.97000000000003" height="8.0"
#                                   fill="none" stroke="rgba(255, 165, 0, 0.85)" stroke-width="1.5" />
#
#                             <div class="pdf-element" data-element-id="2" style="position: absolute; pointer-events: auto; cursor: pointer; left: 385.0px; top: 45.66px; width: 81.35000000000002px; height: 8.0px; background-color: rgba(200, 200, 200, 0.3); border: 1px dashed transparent; "></div>
#
#                             <rect data-element-id="2" x="385.0" y="45.66" width="81.35000000000002" height="8.0"
#                                   fill="none" stroke="rgba(255, 165, 0, 0.85)" stroke-width="1.5" />
#
#                             <div class="pdf-element" data-element-id="3" style="position: absolute; pointer-events: auto; cursor: pointer; left: 50.0px; top: 84.07px; width: 24.450000000000003px; height: 10.0px; background-color: rgba(200, 200, 200, 0.3); border: 1px dashed transparent; "></div>
#
#                             <rect data-element-id="3" x="50.0" y="84.07" width="24.450000000000003" height="10.0"
#                                   fill="none" stroke="rgba(255, 165, 0, 0.85)" stroke-width="1.5" />
#
#                             <div class="pdf-element" data-element-id="4" style="position: absolute; pointer-events: auto; cursor: pointer; left: 74.45px; top: 84.07px; width: 107.80999999999999px; height: 10.0px; background-color: rgba(200, 200, 200, 0.3); border: 1px dashed transparent; "></div>
#
#                             <rect data-element-id="4" x="74.45" y="84.07" width="107.80999999999999" height="10.0"
#                                   fill="none" stroke="rgba(255, 165, 0, 0.85)" stroke-width="1.5" />
#
#                             <div class="pdf-element" data-element-id="5" style="position: absolute; pointer-events: auto; cursor: pointer; left: 182.26px; top: 84.07px; width: 52.24000000000001px; height: 10.0px; background-color: rgba(200, 200, 200, 0.3); border: 1px dashed transparent; "></div>
#
#                             <rect data-element-id="5" x="182.26" y="84.07" width="52.24000000000001" height="10.0"
#                                   fill="none" stroke="rgba(255, 165, 0, 0.85)" stroke-width="1.5" />
#
#                             <div class="pdf-element" data-element-id="6" style="position: absolute; pointer-events: auto; cursor: pointer; left: 50.0px; top: 104.07px; width: 30.560000000000002px; height: 10.0px; background-color: rgba(200, 200, 200, 0.3); border: 1px dashed transparent; "></div>
#
#                             <rect data-element-id="6" x="50.0" y="104.07" width="30.560000000000002" height="10.0"
#                                   fill="none" stroke="rgba(255, 165, 0, 0.85)" stroke-width="1.5" />
#
#                             <div class="pdf-element" data-element-id="7" style="position: absolute; pointer-events: auto; cursor: pointer; left: 80.56px; top: 104.07px; width: 76.15px; height: 10.0px; background-color: rgba(200, 200, 200, 0.3); border: 1px dashed transparent; "></div>
#
#                             <rect data-element-id="7" x="80.56" y="104.07" width="76.15" height="10.0"
#                                   fill="none" stroke="rgba(255, 165, 0, 0.85)" stroke-width="1.5" />
#
#                             <div class="pdf-element" data-element-id="8" style="position: absolute; pointer-events: auto; cursor: pointer; left: 50.0px; top: 124.07px; width: 80.0px; height: 10.0px; background-color: rgba(200, 200, 200, 0.3); border: 1px dashed transparent; "></div>
#
#                             <rect data-element-id="8" x="50.0" y="124.07" width="80.0" height="10.0"
#                                   fill="none" stroke="rgba(255, 165, 0, 0.85)" stroke-width="1.5" />
#
#                             <div class="pdf-element" data-element-id="9" style="position: absolute; pointer-events: auto; cursor: pointer; left: 130.0px; top: 124.07px; width: 5.560000000000002px; height: 10.0px; background-color: rgba(200, 200, 200, 0.3); border: 1px dashed transparent; "></div>
#
#                             <rect data-element-id="9" x="130.0" y="124.07" width="5.560000000000002" height="10.0"
#                                   fill="none" stroke="rgba(255, 165, 0, 0.85)" stroke-width="1.5" />
#
#                             <div class="pdf-element" data-element-id="10" style="position: absolute; pointer-events: auto; cursor: pointer; left: 50.0px; top: 144.07px; width: 51.68000000000001px; height: 10.0px; background-color: rgba(200, 200, 200, 0.3); border: 1px dashed transparent; "></div>
#
#                             <rect data-element-id="10" x="50.0" y="144.07" width="51.68000000000001" height="10.0"
#                                   fill="none" stroke="rgba(255, 165, 0, 0.85)" stroke-width="1.5" />
#
#                             <div class="pdf-element" data-element-id="11" style="position: absolute; pointer-events: auto; cursor: pointer; left: 101.68px; top: 144.07px; width: 404.61px; height: 10.0px; background-color: rgba(200, 2
# SimpleInteractiveViewerWidget()
